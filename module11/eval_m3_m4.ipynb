# %% [markdown]
# # 📝 Workshop 2 · Evaluation — Modules 3 & 4
# ### Course: Python from Scratch for Data Analysis
#
# **Topics:** Lists · Dictionaries · List of dictionaries · Functions · Docstrings · Multiple returns
#
# ---
#
# **Instructions**
#
# - Work through each exercise in order.
# - Read the problem statement carefully — **twice** — before writing any code.
# - Use the *Before you code* section to plan before you type.
# - Every exercise has a pattern label — use it as a clue.
# - You may not use any imports. All exercises use only built-in Python.
#
# **Time:** approximately 60 minutes total.

# %% [markdown]
# ---
#
# ## Exercise 1 — Lists ★☆☆
# *(Module 3)*
#
# A student has recorded her quiz grades:
# ```python
# grades = [3.5, 4.2, 2.8, 3.0, 4.5]
# ```
#
# **Task:**
#
# 1. Add a new grade `3.8` to the end of the list.
# 2. Remove the grade `2.8` from the list.
# 3. Sort the list in **descending** order (highest first).
# 4. Print the resulting list.
# 5. Print the highest grade, the lowest grade, and the total count.
#
# Expected output:
# ```
# Sorted grades: [4.5, 4.2, 3.8, 3.5, 3.0]
# Highest: 4.5
# Lowest:  3.0
# Count:   5
# ```
#
# ---
#
# **Before you code**
#
# - **Input:** `grades` (list of floats)
# - **Output:** printed sorted list + three printed statistics
# - **Steps:**
#   1. Use `.append()` to add 3.8.
#   2. Use `.remove()` to delete 2.8.
#   3. Use `.sort(reverse=True)` to sort descending.
#   4. Print the list.
#   5. Print `grades[0]` (highest), `grades[-1]` (lowest), `len(grades)` (count).
# - **Pattern:** no loop — direct list operations.

# %%
# Exercise 1: list operations.

grades = [3.5, 4.2, 2.8, 3.0, 4.5]

# Step 1: add a new grade to the end.
# TODO: append 3.8 to the list.
pass

# Step 2: remove the failing grade.
# TODO: remove 2.8 from the list.
pass

# Step 3: sort in descending order.
# TODO: sort the list from highest to lowest.
pass

# Step 4: print the sorted list.
# TODO: print "Sorted grades: [...]"
pass

# Step 5: print the three statistics.
# TODO: print highest, lowest, and count.
pass

# %% [markdown]
# ---
#
# ## Exercise 2 — Dictionaries ★★☆
# *(Module 3)*
#
# A store has this product in its system:
#
# ```python
# product = {
#     "name":     "Calculadora científica",
#     "price_cop": 85_000,
#     "stock":     12,
#     "category": "school supplies"
# }
# ```
#
# **Task:**
#
# 1. Apply a **15% discount** to the price. Update the `"price_cop"` key (convert to `int`).
# 2. Three units were sold. Decrease `"stock"` by 3.
# 3. Add a new key `"on_sale"` with the value `True`.
# 4. Loop through all key-value pairs using `.items()` and print each one.
#
# Expected output:
# ```
# name      → Calculadora científica
# price_cop → 72,250 COP
# stock     → 9
# category  → school supplies
# on_sale   → True
# ```
#
# ---
#
# **Before you code**
#
# - **Input:** `product` dictionary with 4 keys
# - **Output:** updated dictionary printed key by key
# - **Steps:**
#   1. Compute `new_price = int(product["price_cop"] * 0.85)` and assign it back.
#   2. Subtract 3 from `product["stock"]`.
#   3. Assign `product["on_sale"] = True`.
#   4. Loop over `product.items()` and print each pair.
# - **Pattern:** no loop for steps 1–3; one loop for step 4.

# %%
# Exercise 2: dictionary operations.

product = {
    "name":      "Calculadora cient\u00edfica",
    "price_cop":  85_000,
    "stock":      12,
    "category":  "school supplies"
}

# Step 1: apply a 15% discount (keep only 85% of the price).
# TODO: update product["price_cop"] with the discounted price (int).
pass

# Step 2: 3 units were sold — decrease stock.
# TODO: subtract 3 from product["stock"].
pass

# Step 3: add the "on_sale" flag.
# TODO: add key "on_sale" with value True.
pass

# Step 4: print all key-value pairs using a loop.
# TODO: loop over product.items() and print each key → value.
pass

# %% [markdown]
# ---
#
# ## Exercise 3 — List of dictionaries ★★☆
# *(Module 3)*
#
# A university keeps records of four students:
#
# ```python
# students = [
#     {"name": "Camila",  "gpa": 4.8, "program": "Engineering"},
#     {"name": "Andr\u00e9s",  "gpa": 2.9, "program": "Medicine"},
#     {"name": "Sof\u00eda",   "gpa": 3.7, "program": "Business"},
#     {"name": "Miguel",  "gpa": 2.4, "program": "Business"},
# ]
# ```
#
# **Task:**
#
# 1. **Filter:** Print the names and GPAs of all students with GPA ≥ 3.5 (the "honor roll").
# 2. **Tracker:** Find and print the student with the highest GPA (name and GPA).
#
# Expected output:
# ```
# Honor roll (GPA ≥ 3.5):
#   - Camila  (Engineering): 4.8
#   - Sofía   (Business):    3.7
#
# Top student: Camila — 4.8 GPA
# ```
#
# ---
#
# **Before you code**
#
# - **Input:** `students` (list of 4 dictionaries)
# - **Output:** (1) filtered list of honor-roll students; (2) single top-student line
# - **Steps:**
#   1. Print the header line.
#   2. Loop through students. If `s["gpa"] >= 3.5`, print name, program, gpa.
#   3. Before the second loop, set `best = students[0]` (a tracker starting point).
#   4. Loop through all students. If `s["gpa"] > best["gpa"]`, update `best = s`.
#   5. After the loop, print the best student.
# - **Pattern:** Filter (Part 1) + Tracker (Part 2)

# %%
# Exercise 3: list of dictionaries — filter and tracker.

students = [
    {"name": "Camila",  "gpa": 4.8, "program": "Engineering"},
    {"name": "Andr\u00e9s",  "gpa": 2.9, "program": "Medicine"},
    {"name": "Sof\u00eda",   "gpa": 3.7, "program": "Business"},
    {"name": "Miguel",  "gpa": 2.4, "program": "Business"},
]

# Part 1: FILTER — honor roll (GPA >= 3.5).
print("Honor roll (GPA \u2265 3.5):")
# TODO: loop through students.
#       If s["gpa"] >= 3.5, print the student's name, program, and gpa.
pass

# Part 2: TRACKER — find the top student.
# TODO: initialize 'best' to the first student.
# TODO: loop through all students.
#       If s["gpa"] > best["gpa"], update best.
# TODO: print the top student's name and gpa.
pass

# %% [markdown]
# ---
#
# ## Exercise 4 — Function with docstring ★★☆
# *(Module 4)*
#
# **Task:**
#
# Write a function `classify_gpa(gpa)` that:
# - Takes a single float argument `gpa` (between 0.0 and 5.0).
# - Returns a **string** with the classification:
#
#   | GPA | Returns |
#   |-----|---------|
#   | ≥ 4.5 | `"Distinción de honor"` |
#   | ≥ 3.5 | `"Buen rendimiento"` |
#   | ≥ 2.5 | `"Rendimiento promedio"` |
#   | < 2.5 | `"En riesgo académico"` |
#
# - Has a proper **docstring** (description, Args section, Returns section).
#
# After writing the function, **test it** with at least 4 `assert` statements covering different cases.
# Call it a few times to show the output.
#
# ---
#
# **Before you code**
#
# - **Input:** one float `gpa`
# - **Output:** one string (the classification)
# - **Steps:**
#   1. Write `def classify_gpa(gpa):` followed by a triple-quoted docstring.
#   2. Inside the function, write an if/elif/elif/else block.
#   3. Each branch returns the corresponding string.
#   4. After the function, write 4 assert statements to test it.
#   5. Print a few calls to see the output.
# - **Pattern:** no loop inside the function — pure conditional logic.

# %%
# Exercise 4: function with docstring.

# TODO: define the function classify_gpa(gpa).
#       Include a docstring with description, Args, and Returns sections.
#       Inside, use if/elif/elif/else to return the correct classification.

def classify_gpa(gpa):
    pass   # Replace this with your implementation.


# TODO: write 4 assert statements to test your function.
# Example: assert classify_gpa(4.8) == "Distinción de honor"
pass

# TODO: call the function a few times and print the results.
pass

# %% [markdown]
# ---
#
# ## Exercise 5 — Function with multiple returns ★★☆
# *(Module 4)*
#
# **Task:**
#
# Write a function `analyze_scores(scores)` that:
# - Takes a list of floats.
# - Returns **three values** in a single `return` statement: `(average, highest, lowest)`.
# - Has a proper **docstring**.
#
# Then call the function with `scores = [3.5, 4.2, 2.8, 4.0, 3.7]`
# and print the three results on separate lines.
#
# Expected output:
# ```
# Average: 3.64
# Highest: 4.2
# Lowest:  2.8
# ```
#
# ---
#
# **Before you code**
#
# - **Input:** `scores` (list of floats)
# - **Output:** three values returned; printed by the caller
# - **Steps:**
#   1. Define `analyze_scores(scores)` with a docstring.
#   2. Inside: compute average = sum of scores / count of scores, round to 2.
#   3. Compute highest = the maximum value in the list.
#   4. Compute lowest = the minimum value in the list.
#   5. Return all three: `return average, highest, lowest`.
#   6. Outside: call the function, unpack into 3 variables, print each.
# - **Pattern:** Accumulator (sum + count) inside the function.

# %%
# Exercise 5: function with multiple returns.

# TODO: define analyze_scores(scores).
#       Docstring required.
#       Return (average, highest, lowest).

def analyze_scores(scores):
    pass   # Replace this with your implementation.


# Call the function with the provided scores.
scores = [3.5, 4.2, 2.8, 4.0, 3.7]

# TODO: call analyze_scores(scores) and unpack the three return values.
# TODO: print average, highest, and lowest on separate lines.
pass

# %% [markdown]
# ---
#
# ## Exercise 6 — Mini-project: functions + list of dictionaries ★★★
# *(Modules 3 & 4)*
#
# A company has 5 employees in three departments:
#
# ```python
# employees = [
#     {"name": "Valentina", "department": "Marketing",    "salary": 2_800_000},
#     {"name": "Santiago",  "department": "Engineering",  "salary": 4_200_000},
#     {"name": "Camila",    "department": "Marketing",    "salary": 3_100_000},
#     {"name": "Andrés",    "department": "Engineering",  "salary": 3_800_000},
#     {"name": "Isabella",  "department": "HR",           "salary": 2_500_000},
# ]
# ```
#
# **Task:**
#
# 1. Write a function `average_salary_by_department(employees)` that:
#    - Takes the list of employee dictionaries.
#    - Returns a **dictionary** mapping each department name to its **average salary** (rounded to 0 decimal places, as an int).
#    - Has a proper docstring.
#
# 2. Call the function and print the result, formatted like:
#    ```
#    Engineering:  4,000,000 COP/month
#    HR:           2,500,000 COP/month
#    Marketing:    2,950,000 COP/month
#    ```
#
# ---
#
# **Before you code**
#
# - **Input:** `employees` (list of dicts, each with "department" and "salary")
# - **Output:** a dict `{dept: avg_salary}`, then printed
# - **Steps:**
#   1. Inside the function, create two dictionaries: `totals = {}` and `counts = {}`.
#   2. Loop through employees. For each employee:
#      - If the department is not yet in `totals`, add it with value 0 (and 0 in counts).
#      - Add the salary to `totals[dept]`.
#      - Add 1 to `counts[dept]`.
#   3. Build a result dict: for each dept, compute `int(totals[dept] / counts[dept])`.
#   4. Return the result dict.
#   5. Outside: call the function, loop over the result sorted alphabetically, print each line.
# - **Pattern:** Accumulator (building totals and counts per group)

# %%
# Exercise 6: mini-project — average salary by department.

employees = [
    {"name": "Valentina", "department": "Marketing",   "salary": 2_800_000},
    {"name": "Santiago",  "department": "Engineering", "salary": 4_200_000},
    {"name": "Camila",    "department": "Marketing",   "salary": 3_100_000},
    {"name": "Andr\u00e9s",  "department": "Engineering", "salary": 3_800_000},
    {"name": "Isabella",  "department": "HR",          "salary": 2_500_000},
]


# TODO: define average_salary_by_department(employees).
#       Docstring required.
#       Return a dict: {department_name: average_salary_as_int}.

def average_salary_by_department(employees):
    pass   # Replace this with your implementation.


# TODO: call the function and print each department's average salary.
# Sort the output alphabetically by department name.
# Format: "Engineering:  4,000,000 COP/month"
pass
