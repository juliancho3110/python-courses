# %% [markdown]
# # 📦 Module 3 · Data Structures
# ### Course: Python from Scratch for Data Analysis
#
# ---
#
# **Prerequisites:** Modules 1 & 2 — variables, types, operators, conditionals, loops
#
# ### What you will learn today
# 0. Programming thinking — how to translate any problem into code
# 1. Lists — ordered collections of items
# 2. List methods and common operations
# 3. Dictionaries — key-value data storage
# 4. Combining lists and dictionaries
# 5. Mini-project — student grade tracker
#
# > **Why does this matter for data analysis?** A spreadsheet column is essentially a list. A spreadsheet row is essentially a dictionary. Master these two structures and you already think like a data analyst.

# %% [markdown]
# ---
# ## 🧠 Block 0 — Programming Thinking: From Problem to Code
#
# Before we write any new Python syntax, we need to address something more important: **how do you turn a sentence like “find the student with the highest grade” into actual working code?**
#
# This is the skill that separates someone who understands syntax from someone who can actually program. It is not obvious. It is not natural. It is a learned process — and this block gives you that process.

# %% [markdown]
# ### The recipe analogy
#
# Imagine a friend asks you: *“Make a fruit salad.”*
#
# You do not grab a random piece of fruit and start cutting. You think:
# 1. Which fruits do I have? **(inputs)**
# 2. What should the salad look like at the end? **(output)**
# 3. What steps do I follow in order? **(decomposition)**
#
# Programming works exactly the same way.
#
# - The **problem statement** is the request.
# - Your **data** (a list, a dictionary) is the raw ingredients.
# - The **code** is the sequence of steps that turns ingredients into the finished result.
#
# The skill you are building is learning how to **write that recipe** — before you touch the keyboard.

# %% [markdown]
# ### The 5-step process
#
# Every time you face a programming problem, follow these five steps in order.
#
# | Step | What to do | Key question |
# |------|------------|--------------|
# | **1. Read** | Read the whole problem — twice. Do not touch the keyboard yet. | *What is this actually asking me to do?* |
# | **2. Identify** | Name your inputs and outputs explicitly. | *What data do I have? What do I need to produce?* |
# | **3. Decompose** | Break the problem into 3–5 small steps. | *What must happen first? Then what?* |
# | **4. Pseudocode** | Write each step as a sentence, one per line. | *Can I read each step out loud and have it make sense?* |
# | **5. Translate** | Convert each pseudocode line to Python, one at a time. | *Which Python tool maps to this sentence?* |
#
# > **Rule:** If you are staring at a blank cell and do not know what to type, you skipped a step. Go back to Step 1 and do not jump ahead.

# %% [markdown]
# ### Worked example — the full 5-step process in action
#
# **Problem statement:**
# *“You have a list of student grades. Calculate the average and print whether the student passed (average ≥ 3.0) or failed.”*
#
# ---
#
# **Step 1 — Read carefully**
# Reading twice reveals two tasks: (1) calculate an average, (2) compare it to 3.0 and print a message.
#
# ---
#
# **Step 2 — Identify inputs and outputs**
# - **Input:** a list of numbers (grades)
# - **Output:** one number (the average) + one string (`"Passed"` or `"Failed"`)
#
# ---
#
# **Step 3 — Decompose**
# 1. Add up all the grades → get a total.
# 2. Divide the total by the number of grades → get the average.
# 3. If average ≥ 3.0 → student passed. Otherwise → student failed.
# 4. Print the result.
#
# ---
#
# **Step 4 — Pseudocode** *(plain English — no Python syntax yet)*
# ```
# Store a running total, starting at zero.
# Go through each grade one by one:
#     Add that grade to the running total.
# Compute the average: divide the total by how many grades there are.
# If the average is 3.0 or more → the student passed.
# Otherwise → the student failed.
# Print the result showing the average.
# ```
#
# > **Rule for pseudocode:** write full English sentences. If it looks like Python, you skipped a step.
#
# ---
#
# **Step 5 — Translate** → first read the mapping table in the next cell, then look at the code.

# %% [markdown]
# ### Step 5 — The translation table: pseudocode sentence → Python line
#
# Each row answers the question: *“which Python tool maps to this sentence?”*
#
# | Pseudocode sentence | Python tool needed | Python line |
# |---------------------|--------------------|-------------|
# | “Store a running total, starting at zero” | Variable assignment | `total = 0` |
# | “Go through each grade one by one” | `for` loop | `for grade in grades:` |
# | “Add that grade to the running total” | `+=` operator | `total += grade` |
# | “Divide the total by how many grades there are” | Division + `len()` | `average = total / len(grades)` |
# | “If the average is 3.0 or more” | `if` + `>=` | `if average >= 3.0:` |
# | “Otherwise” | `else` | `else:` |
# | “Print the result showing the average” | `print()` + f-string | `print(f"Average: {average:.2f} — ...")` |
#
# > **Notice:** the pseudocode sentence describes the *intention*. The Python line is the *tool* the language gives you to express that intention. Your job in Step 5 is always to find the right tool for each intention.

# %%
# STEP 5: Translating each pseudocode sentence to Python.
grades = [3.5, 2.8, 4.0, 3.2, 3.9]   # Input: the list of grades.

# “Store a running total, starting at zero.”
total = 0

# “Go through each grade one by one: add that grade to the running total.”
for grade in grades:
    total += grade
# Round 1: grade = 3.5  →  total = 0    + 3.5 = 3.5
# Round 2: grade = 2.8  →  total = 3.5  + 2.8 = 6.3
# Round 3: grade = 4.0  →  total = 6.3  + 4.0 = 10.3
# Round 4: grade = 3.2  →  total = 10.3 + 3.2 = 13.5
# Round 5: grade = 3.9  →  total = 13.5 + 3.9 = 17.4

# “Compute the average: divide the total by how many grades there are.”
average = total / len(grades)

# “If the average is 3.0 or more → the student passed. Otherwise → failed.”
if average >= 3.0:
    print(f"Average: {average:.2f} — Passed ✓")
else:
    print(f"Average: {average:.2f} — Failed ✗")

# %% [markdown]
# ### The three fundamental patterns
#
# Almost every programming problem you will encounter in this course follows one of three patterns.
# **Recognizing the pattern before you start typing** is the single most useful habit you can build.
#
# | Pattern | The problem asks you to... | Starting template |
# |---------|---------------------------|-------------------|
# | **Accumulator** | calculate a total, sum, count, average | `total = 0` → loop → `total += x` |
# | **Tracker** | find the highest, lowest, best, worst item | `best = list[0]` → loop → `if x > best: best = x` |
# | **Filter** | list all items that match a condition | `result = []` → loop → `if condition: result.append(x)` |
#
# Study the next three cells carefully. You will use these patterns in every exercise.

# %%
# PATTERN 1 — ACCUMULATOR
# Problem: "Calculate the total amount spent on travel expenses."
#
# Pattern recognition:
#   "calculate the total" → Accumulator.
#   I have: a list of amounts.  I need: one number (the sum).
#   Template: start at 0, add each amount inside a loop.

travel_expenses = [320000, 85000, 540000, 210000, 95000]  # COP

total = 0                         # Start the accumulator at zero.
for amount in travel_expenses:
    total += amount               # Add each amount to the running total.
# Round 1: amount = 320000  →  total = 0       + 320000 = 320000
# Round 2: amount =  85000  →  total = 320000  +  85000 = 405000
# Round 3: amount = 540000  →  total = 405000  + 540000 = 945000
# Round 4: amount = 210000  →  total = 945000  + 210000 = 1155000
# Round 5: amount =  95000  →  total = 1155000 +  95000 = 1250000

print(f"Total travel expenses: {total:,} COP")
# Out:
# Total travel expenses: 1,250,000 COP

# %%
# PATTERN 2 — TRACKER
# Problem: "Find the most expensive travel expense."
#
# Pattern recognition:
#   "find the highest" → Tracker.
#   I have: a list of amounts.  I need: one number (the maximum).
#   Template: assume the first is the best, compare every other item against it.

travel_expenses = [320000, 85000, 540000, 210000, 95000]  # COP

highest = travel_expenses[0]      # Assume the first is the highest.
for amount in travel_expenses:
    if amount > highest:
        highest = amount          # Update only when we find something bigger.
# Round 1: amount = 320000  →  320000 > 320000? No  →  highest = 320000
# Round 2: amount =  85000  →   85000 > 320000? No  →  highest = 320000
# Round 3: amount = 540000  →  540000 > 320000? Yes →  highest = 540000
# Round 4: amount = 210000  →  210000 > 540000? No  →  highest = 540000
# Round 5: amount =  95000  →   95000 > 540000? No  →  highest = 540000

print(f"Most expensive trip: {highest:,} COP")
# Out:
# Most expensive trip: 540,000 COP

# %%
# PATTERN 3 — FILTER
# Problem: "List all travel expenses over 200,000 COP."
#
# Pattern recognition:
#   "list all items that..." → Filter.
#   I have: a list of amounts.  I need: a shorter list (only those that qualify).
#   Template: start with an empty list, add items that pass the condition.

travel_expenses = [320000, 85000, 540000, 210000, 95000]  # COP

expensive_trips = []              # Start with an empty result.
for amount in travel_expenses:
    if amount > 200000:
        expensive_trips.append(amount)   # Only add it if it qualifies.
# Round 1: 320000 > 200000? Yes →  expensive_trips = [320000]
# Round 2:  85000 > 200000? No  →  expensive_trips = [320000]
# Round 3: 540000 > 200000? Yes →  expensive_trips = [320000, 540000]
# Round 4: 210000 > 200000? Yes →  expensive_trips = [320000, 540000, 210000]
# Round 5:  95000 > 200000? No  →  expensive_trips = [320000, 540000, 210000]

print(f"Expensive trips: {expensive_trips}")
print(f"Count: {len(expensive_trips)}")

# %% [markdown]
# > **From here on — before every exercise:**
# > 1. Identify the pattern: *Accumulator, Tracker, or Filter?*
# > 2. Apply the 5 steps.
# > 3. Write at least two lines of pseudocode as comments before you start coding.

# %% [markdown]
# ---
# ## 📋 Block 1 — Lists
#
# A **list** is an ordered collection of items. Items can be of any type, and the list can grow or shrink.
#
# ```python
# my_list = [item1, item2, item3]
# ```
#
# Think of it as a column in a spreadsheet — ordered, and each item has a position (index).

# %%
# Creating lists.
grades      = [3.5, 2.8, 4.0, 3.2, 3.9]
students    = ["Alice", "Bob", "Carol", "David"]
mixed       = ["Alice", 21, 3.8, True]   # Lists can mix types (though unusual in data).
empty_list  = []                          # An empty list.

print(grades)
print(students)
print(f"Number of grades: {len(grades)}")
print(f"Number of elements mixed list:{len(mixed)}")
# Out:
# [3.5, 2.8, 4.0, 3.2, 3.9]
# ['Alice', 'Bob', 'Carol', 'David']
# Number of grades: 5
# Number of elements mixed list:4

# %% [markdown]
# ### Indexing — accessing individual items
#
# Python counts positions starting from **0**, not 1. Negative indices count from the end.
#
# ```
# grades = [3.5,  2.8,  4.0,  3.2,  3.9]
# index:     0     1     2     3     4
# negative: -5    -4    -3    -2    -1
# ```

# %%
grades = [3.5, 2.8, 4.0, 3.2, 3.9]

print(grades[0])    # First item.
print(grades[2])    # Third item.
print(grades[-1])   # Last item.
print(grades[-2])   # Second to last.
# Out:
# 3.5
# 4.0
# 3.9
# 3.2

# %%
# Read the error before fixing it.
print(grades[10])   # Index does not exist.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Read the error before fixing it.
# ----> 2 print(grades[10])   # Index does not exist.
#
# IndexError: list index out of range

# %% [markdown]
# ### Slicing — extracting a portion of a list
#
# `list[start:stop]` — returns items from `start` up to (not including) `stop`.

# %%
grades = [3.5, 2.8, 4.0, 3.2, 3.9]

print(grades[1:3])    # Items at index 1 and 2.
print(grades[:3])     # From start up to index 2.
print(grades[2:])     # From index 2 to end.
print(grades[::2])    # Every other item (step = 2).
print(grades[::-1])   # Reversed list.
# Out:
# [2.8, 4.0]
# [3.5, 2.8, 4.0]
# [4.0, 3.2, 3.9]
# [3.5, 4.0, 3.9]
# [3.9, 3.2, 4.0, 2.8, 3.5]

# %% [markdown]
# ### List methods — modifying a list
#
# A **method** is a function attached to an object. You call it with a dot: `list.method()`.

# %%
grades = [3.5, 2.8, 4.0]
print(f"Original:           {grades}")

# append — add one item to the end.
grades.append(3.2)
print(f"After append:       {grades}")

# insert — add at a specific position.
grades.insert(1, 4.5)
print(f"After insert at 1:  {grades}")

# remove — delete the first occurrence of a value.
grades.remove(2.8)
print(f"After remove 2.8:   {grades}")

# pop — remove and return the item at a position (default: last).
last = grades.pop()
print(f"Popped: {last}  →  List: {grades}")

# sort — sort in place.
grades.sort()
print(f"Sorted:             {grades}")

# reverse — reverse in place.
grades.reverse()
print(f"Reversed:           {grades}")
# Out:
# Original:           [3.5, 2.8, 4.0]
# After append:       [3.5, 2.8, 4.0, 3.2]
# After insert at 1:  [3.5, 4.5, 2.8, 4.0, 3.2]
# After remove 2.8:   [3.5, 4.5, 4.0, 3.2]
# Popped: 3.2  →  List: [3.5, 4.5, 4.0]
# Sorted:             [3.5, 4.0, 4.5]
# Reversed:           [4.5, 4.0, 3.5]

# %%
grades = [3.5, 2.8, 4.0, 3.2, 3.9]

# Built-in functions that work on lists.
print(f"Length : {len(grades)}")
print(f"Sum    : {sum(grades)}")
print(f"Min    : {min(grades)}")
print(f"Max    : {max(grades)}")
print(f"Average: {sum(grades) / len(grades):.2f}")

# Check membership.
print(f"Is 4.0 in the list? {4.0 in grades}")
print(f"Is 5.0 in the list? {5.0 in grades}")
# Out:
# Length : 5
# Sum    : 17.4
# Min    : 2.8
# Max    : 4.0
# Average: 3.48
# Is 4.0 in the list? True
# Is 5.0 in the list? False

# %% [markdown]
# ### ✏️ Exercise 1
# Starting from the list below:
# 1. Print the first and last item
# 2. Add `"grape"` to the end and `"kiwi"` at position 2
# 3. Remove `"banana"`
# 4. Print the list sorted alphabetically
# 5. Print how many fruits are in the final list

# %% [markdown]
# **🧠 Before you code — apply the 5 steps:**
#
# - **Input:** `fruits` — a list of 5 strings
# - **Output:** two printed items, a modified + sorted list, a count
#
# **Decompose** *(no loop needed — each step is one direct operation on the list):*
# 1. Get the first item and the last item → print both.
# 2. Add `"grape"` to the end of the list.
# 3. Insert `"kiwi"` at position 2 (the third slot, counting from zero).
# 4. Remove `"banana"` from the list.
# 5. Sort the list alphabetically → print the whole list.
# 6. Count how many items remain.
#
# **Pseudocode:**
# ```
# Get first item and last item → print both.
# Add "grape" to the end.
# Insert "kiwi" as the third item.
# Remove "banana".
# Sort the list → print it.
# Count how many items are left → print the count.
# ```
#
# **Pattern?** No loop needed — each step is a direct method call on the list.
#
# > **Before running:** after steps 2–4, how many items will be in the list? Predict first.

# %%
fruits = ["apple", "mango", "banana", "orange", "pear"]

# Write your code here
print(fruits[0])
print(fruits[-1])

fruits.append("grape")
fruits.insert(2,"kiwi")
fruits.remove("banana")
fruits.sort()
print(fruits)
print(len(fruits))
# Out:
# apple
# pear
# ['apple', 'grape', 'kiwi', 'mango', 'orange', 'pear']
# 6

# %% [markdown]
# ---
# ## 🗂️ Block 2 — Dictionaries
#
# A **dictionary** stores data as **key-value pairs**. Instead of a position (index), you access values by a meaningful key.
#
# ```python
# my_dict = {"key1": value1, "key2": value2}
# ```
#
# Think of it as a single row in a spreadsheet — each column name is a key, and the cell content is the value.

# %%
# A student record.
student = {
    "name"    : "Alice Johnson",
    "age"     : 21,
    "major"   : "Data Science",
    "gpa"     : 3.8,
    "enrolled": True
}

print(student)
print(f"Name: {student['name']}")
print(f"GPA : {student['gpa']}")
print(f"major: {student['major']}")
# Out:
# {'name': 'Alice Johnson', 'age': 21, 'major': 'Data Science', 'gpa': 3.8, 'enrolled': True}
# Name: Alice Johnson
# GPA : 3.8
# major: Data Science

# %%
# Adding and modifying values.
student["semester"] = 4          # Add a new key.
student["gpa"]      = 3.9        # Update an existing key.

print(student)

# Removing a key.
del student["enrolled"]
print(f"After del: {student}")
# Out:
# {'name': 'Alice Johnson', 'age': 21, 'major': 'Data Science', 'gpa': 3.9, 'enrolled': True, 'semester': 4}
# After del: {'name': 'Alice Johnson', 'age': 21, 'major': 'Data Science', 'gpa': 3.9, 'semester': 4}

# %%
# Read the error — then use .get() to fix it safely.
print(student["scholarship"])   # Key does not exist.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Read the error — then use .get() to fix it safely.
# ----> 2 print(student["scholarship"])   # Key does not exist.
#
# KeyError: 'scholarship'

# %%
# .get() returns None (or a default) instead of crashing.
print(student.get("scholarship"))            # Returns None.
print(student.get("scholarship", "No data")) # Returns default.
# Out:
# None
# No data

# %% [markdown]
# ### Iterating over a dictionary

# %%
student = {"name": "Alice", "age": 21, "gpa": 3.8, "semester": 4}

# Iterate over keys.
for key in student:
    print(key)

print("---")

# Iterate over key-value pairs (most common).
for key, value in student.items():
    print(f"  {key:10}: {value}")
# Out:
# name
# age
# gpa
# semester
# ---
#   name      : Alice
#   age       : 21
#   gpa       : 3.8
#   semester  : 4

# %%
# Useful dictionary methods.
print(list(student.keys()))    # All keys.
print(list(student.values()))  # All values.
print("name" in student)       # Check if a key exists.
# Out:
# ['name', 'age', 'gpa', 'semester']
# ['Alice', 21, 3.8, 4]
# True

# %% [markdown]
# ### ✏️ Exercise 2
# Create a dictionary called `product` representing an item in a store with keys: `name`, `price`, `stock`, `category`.
# Then:
# 1. Print each field using `.items()`
# 2. Apply a 15% discount and update `price`
# 3. Add a key `on_sale` with value `True`
# 4. Print: `"Mango — $1,020 COP (On sale)"`

# %% [markdown]
# **🧠 Before you code — apply the 5 steps:**
#
# - **Input:** nothing yet — you create the dictionary from scratch
# - **Output:** printed fields, an updated price, a new key, a formatted string
#
# **Decompose:**
# 1. Create a dictionary with four fields: name, price (in COP), stock quantity, and category.
# 2. Go through every key–value pair in the dictionary and print each one.
# 3. Apply a 15% discount to the price (keep 85% of the original value).
# 4. Add a new field `"on_sale"` and set it to `True`.
# 5. Print a summary sentence using the name and the updated price.
#
# **Pseudocode:**
# ```
# Create a product with name, price, stock, and category.
# For each field in the product → print the field name and its value.
# Reduce the price by 15% → store the new price back in the product.
# Add an "on_sale" field and set it to true.
# Print a sentence showing the product name and the updated price.
# ```
#
# **Pattern?** No main loop (except for printing all fields). All direct dictionary operations.

# %%
# Write your code here
product={"name":"Mango", "price":1200,"stock":10, "category":"fruits" }
for key, value in product.items():
    print(f"{key}: {value}")
product["price"]=product["price"]*0.85
product["on_sale"]=True
print(f"{product['name']} - {product['price']:.0f} (on sale) {product ['on_sale']} ")
# Out:
# name: Mango
# price: 1200
# stock: 10
# category: fruits
# Mango - 1020 (on sale) True

# %% [markdown]
# ---
# ## 🔗 Block 3 — Combining Lists and Dictionaries
#
# Real data is almost always a **list of dictionaries** — exactly how a spreadsheet works: multiple rows, each with the same fields.
#
# ```
# Spreadsheet row  →  dictionary
# Spreadsheet col  →  list of values with the same key
# Full table       →  list of dictionaries
# ```

# %%
# A small dataset: list of student records.
students = [
    {"name": "Alice",   "gpa": 3.8, "major": "Data Science",  "semester": 4},
    {"name": "Bob",     "gpa": 2.5, "major": "Engineering",    "semester": 2},
    {"name": "Carol",   "gpa": 3.2, "major": "Data Science",   "semester": 6},
    {"name": "David",   "gpa": 1.8, "major": "Business",       "semester": 1},
    {"name": "Eve",     "gpa": 4.0, "major": "Data Science",   "semester": 8},
    {"name": "Frank",   "gpa": 2.9, "major": "Engineering",    "semester": 3},
]

# Access a single row.
print(students[0])

# Access a specific field in a row.
print(students[0]["name"])
print(students[2]["gpa"])
# Out:
# {'name': 'Alice', 'gpa': 3.8, 'major': 'Data Science', 'semester': 4}
# Alice
# 3.2

# %%
# Print all students.
for s in students:
    print(f"  {s['name']:8} | GPA: {s['gpa']} | {s['major']}")
# Out:
#   Alice    | GPA: 3.8 | Data Science
#   Bob      | GPA: 2.5 | Engineering
#   Carol    | GPA: 3.2 | Data Science
#   David    | GPA: 1.8 | Business
#   Eve      | GPA: 4.0 | Data Science
#   Frank    | GPA: 2.9 | Engineering

# %%
# Pattern: FILTER
# Problem: "Print only Data Science students with GPA >= 3.0."
#
# I have: a list of student dicts.  I need: to print a subset.
# Steps: loop over all students -> check two conditions -> print if both are true.

print("Data Science students with GPA >= 3.0:")

for s in students:
    if s["major"] == "Data Science" and s["gpa"] >= 3.0:
        print(f"  {s['name']} — GPA: {s['gpa']}")

# Round 1: Alice | major == DS? Yes | gpa >= 3.0? Yes → print
# Round 2: Bob   | major == DS? No  → skip
# Round 3: Carol | major == DS? Yes | gpa >= 3.0? Yes → print
# Round 4: David | major == DS? No  → skip
# Round 5: Eve   | major == DS? Yes | gpa >= 3.0? Yes → print
# Round 6: Frank | major == DS? No  → skip
# Out:
# Data Science students with GPA >= 3.0:
#   Alice — GPA: 3.8
#   Carol — GPA: 3.2
#   Eve — GPA: 4.0

# %%
# Pattern: ACCUMULATOR
# Problem: "Calculate the average GPA across all students."
#
# I have: a list of student dicts, each with a "gpa" key.
# I need: one number (the class average).
# Steps: accumulate total GPA across all students -> divide by count.

total_gpa = 0                    # Start the accumulator at zero.
for s in students:
    total_gpa += s["gpa"]        # Add this student's GPA to the running total.
# Round 1: s["gpa"] = 3.8  →  total_gpa = 0    + 3.8 = 3.8
# Round 2: s["gpa"] = 2.5  →  total_gpa = 3.8  + 2.5 = 6.3
# Round 3: s["gpa"] = 3.2  →  total_gpa = 6.3  + 3.2 = 9.5
# Round 4: s["gpa"] = 1.8  →  total_gpa = 9.5  + 1.8 = 11.3
# Round 5: s["gpa"] = 4.0  →  total_gpa = 11.3 + 4.0 = 15.3
# Round 6: s["gpa"] = 2.9  →  total_gpa = 15.3 + 2.9 = 18.2

average_gpa = total_gpa / len(students)
print(f"Class average GPA: {average_gpa:.2f}")
# Out:
# Class average GPA: 3.03

# %%
# Pattern: GROUPED ACCUMULATOR (a special variant)
# Problem: "Group students by major — build a dict where each key is a major
#           and the value is a list of student names in that major."
#
# I have: a list of student dicts.  I need: a dictionary of lists.
# Steps:
#   1. Start with an empty dictionary.
#   2. For each student, get their major.
#   3. If we have never seen that major before -> create an empty list for it.
#   4. Append the student's name to the correct major's list.

by_major = {}                    # Start with an empty dictionary.

for s in students:
    major = s["major"]           # Get this student's major.
    if major not in by_major:
        by_major[major] = []     # First time we see this major: create its list.
    by_major[major].append(s["name"])   # Add name to the right major's list.

for major, names in by_major.items():
    print(f"{major}: {names}")
# Out:
# Data Science: ['Alice', 'Carol', 'Eve']
# Engineering: ['Bob', 'Frank']
# Business: ['David']

# %% [markdown]
# ### ✏️ Exercise 3
# Using the `students` list above:
# 1. Print the names of students who are **failing** (GPA < 2.0)
# 2. Find the student with the **highest GPA** without using `max()`
# 3. Count how many students are in each **semester**
# 4. Calculate the **average GPA per major** and print it

# %% [markdown]
# **🧠 Before you code — apply the 5 steps to each sub-problem:**
#
# This exercise has four sub-problems. Identify the pattern for each one before writing any code.
#
# ---
#
# **Sub-problem 1 — “Print failing students”**
# → Pattern: **Filter**
# → Pseudocode:
# ```
# Go through each student one by one.
# If that student's GPA is below 2.0 → print their name.
# ```
#
# ---
#
# **Sub-problem 2 — “Find the student with the highest GPA”**
# → Pattern: **Tracker**
# → Pseudocode:
# ```
# Start by assuming the first student has the best GPA.
# Go through each student.
#     If their GPA is higher than the current best → they become the new best.
# After the loop → print the best student's name and GPA.
# ```
#
# ---
#
# **Sub-problem 3 — “Count students per semester”**
# → Pattern: **Grouped Accumulator** (accumulating into a dictionary, not a single number)
# → Pseudocode:
# ```
# Start with an empty dictionary to hold the counts.
# Go through each student.
#     Add 1 to the count for that student's semester.
# After the loop → print each semester and its count.
# ```
#
# ---
#
# **Sub-problem 4 — “Average GPA per major”**
# → Pattern: **Grouped Accumulator** (two passes: collect totals and counts by major, then divide)
# → Pseudocode:
# ```
# Start with two empty dictionaries: one for GPA totals, one for student counts.
# First pass — go through each student:
#     Add their GPA to the running total for their major.
#     Add 1 to the count for their major.
# Second pass — go through each major:
#     Divide the total GPA by the count → that is the average for that major.
#     Print the major and its average.
# ```
#
# ---
#
# > **Notice:** one exercise can require multiple patterns. Identify each sub-problem separately before writing a single line of code.

# %%
students = [
    {"name": "Alice",   "gpa": 3.8, "major": "Data Science",  "semester": 4},
    {"name": "Bob",     "gpa": 2.5, "major": "Engineering",    "semester": 2},
    {"name": "Carol",   "gpa": 3.2, "major": "Data Science",   "semester": 6},
    {"name": "David",   "gpa": 1.8, "major": "Business",       "semester": 1},
    {"name": "Eve",     "gpa": 4.0, "major": "Data Science",   "semester": 8},
    {"name": "Frank",   "gpa": 2.9, "major": "Engineering",    "semester": 3},
]

# --- Sub-problem 1: Filter — failing students ---
# Pattern: Filter
# Pseudocode: for each student: if gpa < 2.0: print name

#solucionando sub problema:
for s in students:
    if s ["gpa"]<2.0:
        print(f"{s['name']} failed")


# --- Sub-problem 2: Tracker — highest GPA ---
# Pattern: Tracker
# Pseudocode: best = students[0] / for each s: if s["gpa"] > best["gpa"]: best = s

#solucionando sub problema:
best= students[0]
for s in students:
    if s["gpa"]>best["gpa"]:
        best=s
print(f"student with highest gpa is {best['name']} (GPA:{best['gpa']})")

    

# --- Sub-problem 3: Grouped Accumulator — count per semester ---
# Pattern: Grouped Accumulator
# Pseudocode: counts = {} / for each s: counts[s["semester"]] += 1

#solucionando sub problema:
#counts va a ser unn diccionario cuya llave es el semestre y su valor es la cantidad de estudiantes en dicho semestre
#la llave de mi diccionario sera un entero ademas el tipo de valor de un conteo es un entero
#este problema es de patron acumulador por grupos 
counts={}
for s in students:
    sm=s["semester"]
    if sm  not in counts:
        counts[sm]=0
    counts[sm]=counts[sm]+1
print(counts)
    
        


# --- Sub-problem 4: Grouped Accumulator — average GPA per major ---
# Pattern: Grouped Accumulator (two passes)
# Pseudocode: accumulate totals and counts per major, then divide

#solucionando sub problema
#este problema es de patron acumuladir por grupos
total_gpa={}
for s in students:
    major=s["major"]
    if major not in total_gpa:
        total_gpa[major]=0
    total_gpa[major]=total_gpa[major]+s["gpa"]
total_students={}
for s in students:
    major=s["major"]
    if major not in total_students:
        total_students[major]=0
    total_students[major]=total_students[major]+1
for major, gpa in total_gpa.items():
    average=gpa/total_students[major]
    print(f"{major}:{average:.1f}")
# Out:
# David failed
# student with highest gpa is Eve (GPA:4.0)
# {4: 1, 2: 1, 6: 1, 1: 1, 8: 1, 3: 1}
# Data Science:3.7
# Engineering:2.7
# Business:1.8

# %% [markdown]
# ---
# ## 🏗️ Block 4 — Mini-Project: Student Grade Tracker
#
# Build a small grade tracking system using everything from this module.
#
# ### Requirements
# You have a list of students, each with three partial grades. Your program must:
# 1. Calculate each student's average
# 2. Assign a letter grade based on the average
# 3. Determine pass / fail status
# 4. Find the top and bottom student
# 5. Print a formatted class report
#
# **Do not start coding yet.** Read the full decomposition in the next cell first.

# %% [markdown]
# ### 🧠 Full project decomposition — applying the 5 steps
#
# **Step 1 — Read:** This is a large problem, but notice it is really **4 smaller problems stacked together**. Solve them one at a time. Never try to write everything at once.
#
# ---
#
# **Step 2 — Identify inputs and outputs**
# - **Input:** a list of student dictionaries, each with `"name"` and `"grades"` (a list of 3 numbers)
# - **Output:** the same list updated with `"average"`, `"letter"`, and `"passed"` added to each student, plus a printed class report
#
# ---
#
# **Step 3 — Decompose the whole project**
# 1. Go through every student → compute their average → assign a letter grade → decide pass/fail → store all three values inside their data.
# 2. Find the best and worst student by comparing averages (Tracker pattern × 2).
# 3. Compute class-level stats: overall average, total passes, total fails (Accumulator pattern × 3).
# 4. Print the full formatted report: header, one row per student, footer with class stats.
#
# ---
#
# **Step 4 — Pseudocode** *(plain English — no Python syntax yet)*
#
# ```
# SECTION A — Add computed fields to every student:
#   Go through each student one by one.
#   Add up their three grades and divide by 3 → that is their average.
#   Based on the average, assign a letter grade (A, B+, B, C+, C, D, or F).
#   If the average is 2.0 or above → they passed. Otherwise → they failed.
#   Store the average, the letter, and the pass/fail result inside that student's data.
#
# SECTION B — Find the top and bottom student:
#   Assume the first student is both the best and the worst.
#   Go through each student.
#     If their average is higher than the current best → they become the new best.
#     If their average is lower than the current worst → they become the new worst.
#
# SECTION C — Calculate class-level statistics:
#   Start three counters at zero: running total of averages, number of passes, number of fails.
#   Go through each student.
#     Add their average to the running total.
#     If they passed → add 1 to the pass counter. Otherwise → add 1 to the fail counter.
#   Divide the running total by the number of students → that is the class average.
#
# SECTION D — Print the report:
#   Print the table header.
#   Go through each student → print one formatted row with their number, name, average, letter, and status.
#   Print the footer with the class average, pass count, and top/bottom student names.
# ```
#
# ---
#
# **Step 5** is split across four code cells below — one per section. Read the note before each cell.

# %%
# Starter data — do not modify this cell.
students = [
    {"name": "Alice",   "grades": [3.8, 4.0, 3.5]},
    {"name": "Bob",     "grades": [2.1, 1.8, 2.5]},
    {"name": "Carol",   "grades": [3.5, 3.2, 3.8]},
    {"name": "David",   "grades": [1.5, 1.9, 1.7]},
    {"name": "Eve",     "grades": [4.0, 3.9, 4.0]},
    {"name": "Frank",   "grades": [2.8, 3.1, 2.6]},
    {"name": "Grace",   "grades": [3.0, 2.7, 3.3]},
]

# %% [markdown]
# #### Step 1 of 4 — Add average, letter, and passed to each student
#
# **Pattern:** Accumulator inside a loop (for the average) + if/elif/else (for the letter grade)
#
# **Key insight:** You are looping over students and *adding new keys* to each dictionary.
# For the average: add up the three grades and divide by how many there are.
# After this loop, every student dictionary will have three new keys: `"average"`, `"letter"`, `"passed"`.

# %%
# Step 1: Add 'average', 'letter', and 'passed' to each student dictionary.
# Letter scale: A >= 3.7 | B+ >= 3.3 | B >= 3.0 | C+ >= 2.7 | C >= 2.0 | F below 2.0

for s in students:
    # TODO: calculate average from s["grades"]
    pass

    # TODO: assign letter grade using if/elif/else
    pass

    # TODO: assign passed (True if average >= 2.0)
    pass

# %% [markdown]
# #### Step 2 of 4 — Find the top and bottom student
#
# **Pattern:** Tracker — but tracking two values at once (maximum AND minimum)
# **Key insight:** Start with `students[0]` as both the top and the bottom.
# Loop through all students. On each round, ask two questions:
# - Is this average *higher* than the current top? If yes → update `top_student`.
# - Is this average *lower* than the current bottom? If yes → update `bottom_student`.

# %%
# Step 2: Find the top and bottom student by average.
# (Run Step 1 first — students must already have an "average" key.)

# TODO: find top_student and bottom_student (full dicts, not just names)
# Hint: start with students[0] as both, then compare in a loop.

# %% [markdown]
# #### Step 3 of 4 — Calculate class statistics
#
# **Pattern:** Accumulator × 3 — three accumulators running inside the same loop
# **Key insight:** You do not need three separate loops. In a single loop, update `total`, `pass_count`, and `fail_count` all at once — one update per variable per round.

# %%
# Step 3: Calculate class statistics.
# (Run Steps 1 and 2 first.)

# TODO: class_average — average of all student averages
# TODO: pass_count and fail_count

# %% [markdown]
# #### Step 4 of 4 — Print the formatted report
#
# **No new pattern** — this is assembly work.
# **Key insight:** All the data is already computed. This step is pure formatting.
# Use f-strings, `:8` for name padding, `:.2f` for two decimal places, and `:^6` to center a short value.
#
# **Expected output:**
# ```
# =====================================================
#   CLASS GRADE REPORT
# =====================================================
#  # | Name       | Avg  | Letter | Status
# ---+------------+------+--------+--------
#  1 | Alice      | 3.77 |   A    | PASSED
#  2 | Bob        | 2.13 |   C    | PASSED
#  3 | Carol      | 3.50 |  B+    | PASSED
#  4 | David      | 1.70 |   F    | FAILED
#  5 | Eve        | 3.97 |   A    | PASSED
#  6 | Frank      | 2.83 |  C+    | PASSED
#  7 | Grace      | 3.00 |   B    | PASSED
# =====================================================
#   Class average : 3.01
#   Passed        : 6 / 7
#   Top student   : Eve (3.97)
#   Bottom student: David (1.70)
# =====================================================
# ```

# %%
# Step 4: Print the full report.
# (Run Steps 1, 2, and 3 first — all data must be ready.)

# TODO: Build the report using f-strings and all variables from the previous steps.

# %% [markdown]
# ---
# ## 🟠 Optional · Git/GitHub — Staging and .gitignore
#
# > Skip this section if Git was not activated for your course.
#
# ### The staging area
#
# Git has three zones:
#
# ```
# Working directory  →  Staging area  →  Repository
#   (your files)       (git add)        (git commit)
# ```
#
# You **choose** which changes to include in each commit using `git add`.
# This lets you make two unrelated changes and commit them separately with different messages.
#
# ```bash
# # Stage a specific file
# git add module3_data_structures.ipynb
#
# # Stage everything that changed
# git add .
#
# # Check what is staged vs unstaged
# git status
#
# # Unstage a file (without losing the changes)
# git restore --staged module3_data_structures.ipynb
#
# # Commit what is staged
# git commit -m "Add Module 3 notebook — lists and dictionaries"
# ```
#
# ### .gitignore — files Git should never track
#
# Some files should never be committed: temporary files, secrets, large datasets, system files.
#
# Create a file called `.gitignore` in your repo root:
#
# ```
# # .gitignore
#
# # Jupyter Notebook checkpoints
# .ipynb_checkpoints/
#
# # Python cache files
# __pycache__/
# *.pyc
#
# # Data files you do not want to share
# *.csv
# *.xlsx
#
# # OS files
# .DS_Store
# Thumbs.db
# ```
#
# After saving `.gitignore`, run `git status` — those files will no longer appear.
#
# ```bash
# # Commit your .gitignore too
# git add .gitignore
# git commit -m "Add .gitignore for Python and Jupyter files"
# ```
#
# | Command | What it does |
# |---------|-------------|
# | `git add .` | Stages all changed files |
# | `git restore --staged <f>` | Unstages a file |
# | `git diff` | Shows unstaged changes |
# | `git diff --staged` | Shows staged changes |
# | `.gitignore` | Tells Git which files to ignore |

# %% [markdown]
# ---
# ## 🏠 Homework — Module 3
#
# **Estimated time:** 25–30 min
# **Rules:** Create a new `.py` file called `homework_module3.py`. Type everything from scratch — do not copy from the notebook.
#
# ---
#
# ### The problem: monthly expense tracker
#
# You have a list of monthly expenses. Each expense is a dictionary with three fields: `description`, `amount` (COP), and `category`.
#
# ```python
# expenses = [
#     {"description": "Rent",          "amount": 800000, "category": "Housing"},
#     {"description": "Groceries",     "amount": 250000, "category": "Food"},
#     {"description": "Electricity",   "amount": 85000,  "category": "Housing"},
#     {"description": "Transport",     "amount": 120000, "category": "Transport"},
#     {"description": "Netflix",       "amount": 18000,  "category": "Leisure"},
#     {"description": "Lunch out",     "amount": 95000,  "category": "Food"},
#     {"description": "Gym",           "amount": 70000,  "category": "Health"},
#     {"description": "Phone plan",    "amount": 45000,  "category": "Transport"},
#     {"description": "Books",         "amount": 60000,  "category": "Education"},
#     {"description": "Coffee shop",   "amount": 35000,  "category": "Food"},
# ]
# ```
#
# Write a program that:
#
# 1. Calculates the **total expenses** → *Pattern: Accumulator*
# 2. Finds the **most expensive** and **cheapest** item (without using `max()` or `min()`) → *Pattern: Tracker × 2*
# 3. Calculates the **total spent per category** → *Pattern: Grouped Accumulator*
# 4. Identifies the **category with the highest spending** → *Pattern: Tracker on a dictionary*
# 5. Lists all expenses **above $80,000 COP** → *Pattern: Filter*
# 6. Prints a clean formatted report with all of the above
#
# > **Before you write any code:** apply the 5-step process to the whole problem. Write your decomposition as comments at the top of the `.py` file.
#
# ### Bonus (optional)
# Add a variable `monthly_income = 1500000` and calculate what percentage of income each category represents. Include it in the report.
#
# ---
# *Delivery: bring `homework_module3.py` to the next session. It must run without errors.*

# %% [markdown]
# ---
# ## 📋 Module 3 Summary
#
# | Concept | Syntax | Key point |
# |---------|--------|-----------|
# | 5-step process | Read → Identify → Decompose → Pseudocode → Translate | Use it every time you face a blank cell |
# | Accumulator | `total = 0` → loop → `total += x` | Building up a result step by step |
# | Tracker | `best = list[0]` → loop → `if x > best: best = x` | Finding the maximum or minimum |
# | Filter | `result = []` → loop → `if cond: result.append(x)` | Selecting a subset of items |
# | Create list | `[1, 2, 3]` | Ordered collection of items |
# | Index | `list[0]`, `list[-1]` | Access a single item |
# | Slice | `list[1:3]` | Extract a portion |
# | Add item | `.append()`, `.insert()` | Growing a list |
# | Remove item | `.remove()`, `.pop()` | Shrinking a list |
# | List stats | `len()`, `sum()`, `min()`, `max()` | Quick aggregations |
# | Create dict | `{"key": value}` | Named fields (like a spreadsheet row) |
# | Access value | `d["key"]`, `d.get("key")` | Read a field safely |
# | Iterate dict | `for k, v in d.items()` | Loop over all fields |
# | List of dicts | `[{...}, {...}]` | Tabular data (like a full spreadsheet) |
#
# ### Why this matters next
# In **Module 6** you will load a CSV file into Pandas. Under the hood, Pandas represents it as a list of dictionaries — which is exactly what you built today by hand. You already understand what Pandas is actually doing.
#
# ---
# **Next module:** Functions and good coding practices 🛠️
