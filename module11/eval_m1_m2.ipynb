# %% [markdown]
# # 📝 Workshop 1 · Evaluation — Modules 1 & 2
# ### Course: Python from Scratch for Data Analysis
#
# **Topics:** Variables · Types · F-strings · Arithmetic · Conditionals · For loops · While loops
#
# ---
#
# **Instructions**
#
# - Work through each exercise in order.
# - Read the problem statement carefully — **twice** — before writing any code.
# - Use the *Before you code* section to plan before you type.
# - Every exercise has a pattern label — use it as a clue.
# - You may not use any imports. All exercises use only built-in Python.
#
# **Time:** approximately 60 minutes total.

# %% [markdown]
# ---
#
# ## Exercise 1 — Variables and f-strings ★☆☆
# *(Module 1)*
#
# Valentina López is a 20-year-old student who lives in Bogotá.
# She receives a monthly allowance of **450,000 COP**.
#
# **Task:**
#
# 1. Store the four pieces of information in well-named variables.
# 2. Print: `Valentina López is 20 years old and studies in Bogotá.`
# 3. Compute how much she receives **per day** (divide by 30, round to the nearest whole number).
# 4. Print: `Monthly allowance: 450,000 COP → 15,000 COP per day`
#
# ---
#
# **Before you code**
#
# - **Inputs:** name (str), age (int), city (str), allowance (int in COP)
# - **Output:** two printed sentences
# - **Steps:**
#   1. Create one variable for each piece of data.
#   2. Print the first sentence using an f-string.
#   3. Divide the allowance by 30 and round to 0 decimal places — store in a variable.
#   4. Print the second sentence using an f-string.
# - **Pattern:** no loop needed — this is direct variable use.

# %%
# Exercise 1: variables and f-strings.

# Step 1: store the data in variables.
# TODO: create variables for name, age, city, and monthly allowance.
pass

# Step 2: print the first sentence.
# TODO: print "Valentina López is 20 years old and studies in Bogotá."
pass

# Step 3: compute daily allowance.
# TODO: divide monthly allowance by 30 and round to 0 decimal places.
pass

# Step 4: print the second sentence.
# TODO: print "Monthly allowance: 450,000 COP → 15,000 COP per day"
pass

# %% [markdown]
# ---
#
# ## Exercise 2 — Type conversion and arithmetic ★☆☆
# *(Module 1)*
#
# A store sold 4 units of a product whose price is stored as the string `"25500"` (COP).
# The store must add **19% IVA** (Colombian sales tax) to the subtotal.
#
# **Task:**
#
# 1. Convert the price string to an integer.
# 2. Compute `subtotal = price × units`.
# 3. Compute `tax = subtotal × 0.19`.
# 4. Compute `total = subtotal + tax`.
# 5. Print each value on its own line, formatted with commas (e.g., `25,500`).
#
# Expected output:
# ```
# Price per unit: 25,500 COP
# Units sold:     4
# Subtotal:       102,000 COP
# IVA (19%):       19,380 COP
# Total:          121,380 COP
# ```
#
# ---
#
# **Before you code**
#
# - **Inputs:** price as a string `"25500"`, units as an integer `4`
# - **Output:** 5 printed lines with the computed values
# - **Steps:**
#   1. Convert the string to int using `int()`.
#   2. Multiply price × units → subtotal.
#   3. Multiply subtotal × 0.19 → tax (will be a float — convert to int for clean output).
#   4. Add subtotal + tax → total.
#   5. Print all values with f-strings and `:,` formatting.
# - **Pattern:** no loop needed — sequential arithmetic.

# %%
# Exercise 2: type conversion and arithmetic.

# Step 1: the price arrives as a string — convert it.
price_str = "25500"
# TODO: convert price_str to an integer.
pass

# Step 2: compute the subtotal.
units = 4
# TODO: compute subtotal = price × units.
pass

# Step 3: compute IVA (19% tax).
# TODO: compute tax = subtotal * 0.19, then convert to int.
pass

# Step 4: compute the total.
# TODO: compute total = subtotal + tax.
pass

# Step 5: print all values.
# TODO: print each value with commas (use :, inside the f-string).
pass

# %% [markdown]
# ---
#
# ## Exercise 3 — Conditionals ★★☆
# *(Module 2)*
#
# **Part A — Academic classification:**
#
# Given a student's GPA (use `gpa = 3.2`), print the classification:
#
# | GPA | Classification |
# |-----|---------------|
# | ≥ 4.5 | `"Distinción de honor"` |
# | ≥ 3.5 | `"Buen rendimiento"` |
# | ≥ 2.5 | `"Rendimiento promedio"` |
# | < 2.5 | `"En riesgo académico"` |
#
# **Part B — Scholarship eligibility:**
#
# A scholarship requires **both** conditions:
# - The student is in **semester 4 or higher**.
# - The student has a GPA **≥ 3.8**.
#
# Use `semester = 5` and `gpa = 3.2`.
# Print whether the student qualifies and, if not, which condition(s) failed.
#
# ---
#
# **Before you code**
#
# - **Inputs (Part A):** `gpa` (float)
# - **Output (Part A):** one printed classification string
# - **Inputs (Part B):** `gpa` (float), `semester` (int)
# - **Output (Part B):** printed message: qualifies or reason(s) why not
# - **Steps:**
#   1. Write an if/elif/elif/else chain for Part A.
#   2. Write an if with `and` for Part B.
#   3. If not qualifying, use elif to explain which condition failed.
# - **Pattern:** no loop — pure conditional logic.

# %%
# Exercise 3: conditionals.

gpa      = 3.2
semester = 5

# Part A: academic classification.
# TODO: write an if/elif/elif/else block to classify the gpa.
pass

# Part B: scholarship eligibility.
# Conditions: semester >= 4 AND gpa >= 3.8
# TODO: check both conditions and print the result.
#       If the student does not qualify, say which condition(s) failed.
pass

# %% [markdown]
# ---
#
# ## Exercise 4 — For loop · Accumulator ★★☆
# *(Module 2)*
#
# A student completed 5 quizzes. Her scores are:
# ```
# scores = [3.5, 4.2, 2.8, 4.0, 3.7]
# ```
#
# **Task:**
#
# 1. Loop through the scores. For each score, print:
#    `Round 1: 3.5`  `Round 2: 4.2`  … etc.
# 2. While looping, accumulate the total.
# 3. After the loop, compute and print the average (rounded to 2 decimal places).
#
# Expected output:
# ```
# Round 1: 3.5
# Round 2: 4.2
# Round 3: 2.8
# Round 4: 4.0
# Round 5: 3.7
# ─────────────
# Total:   18.2
# Average: 3.64
# ```
#
# ---
#
# **Before you code**
#
# - **Inputs:** `scores` (list of 5 floats)
# - **Output:** 5 lines (one per score) + total + average
# - **Steps:**
#   1. Create a `total` accumulator initialized to 0.
#   2. Use `enumerate()` to get both the index (for the round number) and the score.
#   3. Inside the loop: print the round and score; add the score to total.
#   4. After the loop: compute average = total / number of scores.
#   5. Print total and average.
# - **Pattern:** Accumulator

# %%
# Exercise 4: for loop and accumulator.

scores = [3.5, 4.2, 2.8, 4.0, 3.7]

# Step 1: initialize the accumulator.
# TODO: create a variable 'total' starting at 0.
pass

# Step 2-3: loop through scores, print each round, accumulate.
# TODO: use enumerate() to get the round number (starting at 1) and the score.
#       Print "Round N: score" and add the score to total.
pass

# Step 4-5: compute and print the average.
print("─" * 13)
# TODO: compute average = total / len(scores), round to 2 decimals.
# TODO: print total and average.
pass

# %% [markdown]
# ---
#
# ## Exercise 5 — For loop · Filter ★★☆
# *(Module 2)*
#
# A university shop sells these products and prices (COP):
#
# ```python
# products = ["Cuaderno", "Calculadora", "Lápices", "Mochila", "Regla"]
# prices   = [8_500, 45_000, 3_200, 85_000, 4_500]
# ```
#
# **Task:**
#
# 1. Loop through both lists at the same time using `range(len(...))`.
# 2. Print only the products that cost **less than 10,000 COP** as "affordable".
# 3. Count how many affordable products there are.
# 4. After the loop, print the count.
#
# Expected output:
# ```
# Affordable products (< 10,000 COP):
#   - Cuaderno:  8,500 COP
#   - Lápices:   3,200 COP
#   - Regla:     4,500 COP
# Total affordable: 3
# ```
#
# ---
#
# **Before you code**
#
# - **Inputs:** `products` (list of str), `prices` (list of int)
# - **Output:** lines for each affordable product + a final count line
# - **Steps:**
#   1. Initialize a counter to 0.
#   2. Use `range(len(products))` to loop by index.
#   3. Inside the loop: check if `prices[i] < 10_000`.
#   4. If yes: print the product name and price; add 1 to the counter.
#   5. After the loop: print the total count.
# - **Pattern:** Filter

# %%
# Exercise 5: for loop and filter.

products = ["Cuaderno", "Calculadora", "Lápices", "Mochila", "Regla"]
prices   = [8_500, 45_000, 3_200, 85_000, 4_500]

print("Affordable products (< 10,000 COP):")

# Step 1: initialize the counter.
# TODO: create a variable 'count' starting at 0.
pass

# Step 2-4: loop and filter.
# TODO: use range(len(products)) to loop by index.
#       Check if prices[i] < 10_000.
#       If so, print the product and price, and add 1 to count.
pass

# Step 5: print the count.
# TODO: print "Total affordable: N"
pass

# %% [markdown]
# ---
#
# ## Exercise 6 — While loop · Savings simulator ★★★
# *(Module 2)*
#
# Valentina wants to save enough to buy a laptop that costs **1,200,000 COP**.
# She can put aside **180,000 COP** every month. She starts with **0 savings**.
#
# **Task:**
#
# 1. Use a while loop to simulate her savings month by month.
# 2. Each iteration: add 180,000 to her savings; print:
#    `Month 1: 180,000 COP saved`
# 3. Stop when she reaches or exceeds 1,200,000 COP.
# 4. After the loop, print: `Goal reached in N months!`
#
# Expected output:
# ```
# Month 1:   180,000 COP saved
# Month 2:   360,000 COP saved
# ...
# Month 7: 1,260,000 COP saved
# Goal reached in 7 months!
# ```
#
# ---
#
# **Before you code**
#
# - **Inputs:** `goal = 1_200_000`, `monthly_savings = 180_000`
# - **Output:** one line per month + a final congratulations line
# - **Steps:**
#   1. Initialize `savings = 0` and `month = 0`.
#   2. While savings < goal: add monthly_savings to savings, add 1 to month, print.
#   3. After the loop: print the number of months.
# - **Reminder:** a while loop needs 3 things: (1) initialize before, (2) condition to check, (3) update inside.
# - **Pattern:** Accumulator with while

# %%
# Exercise 6: while loop — savings simulator.

goal           = 1_200_000   # Target amount in COP.
monthly_saving = 180_000     # Amount saved each month.

# Step 1: initialize BEFORE the loop.
# TODO: create variables 'savings' (start at 0) and 'month' (start at 0).
pass

# Step 2: while loop — condition, body, update.
# TODO: write a while loop that:
#       - runs while savings < goal
#       - adds monthly_saving to savings
#       - adds 1 to month
#       - prints "Month N: X,XXX COP saved"
pass

# Step 3: print the final message.
# TODO: print "Goal reached in N months!"
pass
